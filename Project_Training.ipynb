# %% [markdown]
# <a href="https://colab.research.google.com/github/Mask13/CS482_Final_Project/blob/main/Project_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mounting drive and installing Miniconda

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh && bash Miniconda3-latest-Linux-x86_64.sh -bfp /us
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local
# Out:
# --2021-06-24 13:24:08--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 94235922 (90M) [application/x-sh]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>]  89.87M   195MB/s    in 0.5s
#
# 2021-06-24 13:24:09 (195 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh’ saved [94235922/94235922]
#
# PREFIX=/us
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /us
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - brotlipy==0.7.0=py38h27cfd23_1003
#     - ca-certificates==2020.10.14=0
#     - certifi==2020.6.20=pyhd3eb1b0_3
#     - cffi==1.14.3=py38h261ae71_2
#     - chardet==3.0.4=py38h06a4308_1003
# ...

# %% [markdown]
# Checking if its installed correctly

# %%
# !which conda # should return /usr/local/bin/conda
# !conda --version # should return 4.5.4
# !which python # still returns /usr/local/bin/python
# !python --version # now returns Python 3.6.5 :: Anaconda, Inc.
# Out:
# /usr/local/bin/conda
# conda 4.9.2
# /usr/local/bin/python
# Python 3.8.5

# %%
# !conda install --channel defaults conda python=3.8 --yes
# !conda update --channel defaults --all --yes
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#     - python=3.8
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2021.5.25  |       h06a4308_1         112 KB
#     certifi-2021.5.30          |   py38h06a4308_0         138 KB
#     conda-4.10.1               |   py38h06a4308_1         2.9 MB
#     openssl-1.1.1k             |       h27cfd23_0         2.5 MB
#     python-3.8.8               |       hdb3f193_4        50.0 MB
#     ------------------------------------------------------------
#                                            Total:        55.7 MB
#
# The following packages will be UPDATED:
#
#   ca-certificates                              2020.10.14-0 --> 2021.5.25-h06a4308_1
# ...

# %%
# !conda --version # now returns 4.10.1
# !python --version # now returns Python 3.6.13 :: Anaconda, Inc.
# Out:
# conda 4.10.1
# Python 3.8.10

# %%
import sys
sys.path
_ = (sys.path
        .append("/usr/local/lib/python3.6/site-packages"))

# %% [markdown]
# # Installing torch

# %%
# Check cuda version
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0

# %%
# !conda install -c pytorch pytorch --yes
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - pytorch
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |              mkl           6 KB
#     cudatoolkit-10.2.89        |       hfd86e86_1       365.1 MB
#     intel-openmp-2021.2.0      |     h06a4308_610         1.3 MB
#     libuv-1.40.0               |       h7b6447c_0         736 KB
#     mkl-2021.2.0               |     h06a4308_296       144.3 MB
#     ninja-1.10.2               |       hff7bd54_1         1.4 MB
#     pytorch-1.9.0              |py3.8_cuda10.2_cudnn7.6.5_0       705.2 MB  pytorch
#     typing_extensions-3.7.4.3  |     pyha847dfd_0          25 KB
#     ------------------------------------------------------------
#                                            Total:        1.19 GB
#
# ...

# %%
# !pip install tensorboardX
# !pip install torchsummary
# !pip install utm
# !pip install numba
# !pip install imagecodecs
# Out:
# ...
#      |████████████████████████████████| 120 kB 4.3 MB/s
# ...
#      |████████████████████████████████| 15.7 MB 326 kB/s
# ...
#      |████████████████████████████████| 1.0 MB 36.1 MB/s
# ...
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# ...
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# ...
#   Created wheel for utm: filename=utm-0.7.0-py3-none-any.whl size=6093 sha256=39b435cd064279f6f740d6ff0dbf4626f2557f09d2adc25eadd6e782b81bd2ac
#   Stored in directory: /root/.cache/pip/wheels/65/e2/d8/878a8cc986641056fbfebefc4d8eb64238a7b6d3426e86b447
# Successfully built utm
# ...
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# ...
#      |████████████████████████████████| 3.4 MB 4.4 MB/s
# ...

# %% [markdown]
# # Installing packages

# %%
# !conda install gdal=2.4.2 --yes
# !conda install geopandas=0.6.3 --yes
# !conda install fiona --yes
# !conda install rasterio --yes
# !conda installnetworkx=2.2 --yes
# !conda install awscli --yes
# !conda install affine --yes
# !conda install pyproj --yes
# !conda install pyhamcrest --yes
# !conda install cython --yes
# !conda install fiona --yes
# !conda install h5py --yes
# !conda install ncurses --yes
# !conda install jupyterlab --yes
# !conda install ipykernel --yes
# !conda install libgdal --yes
# !conda install ncurses --yes
# !conda install statsmodels --yes
# !conda install pillow --yes
# !conda install scikit-image --yes
# !conda install shapely --yes
# !conda install rtree --yes
# !conda install testpath --yes
# !conda install tqdm --yes
# !pip install opencv-contrib-python
# !conda install jupyterlab --yes
# !conda install ipykernel --yes
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# done
# failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - gdal=2.4.2
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/linux-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/linux-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
# done
# failed with initial frozen solve. Retrying with flexible solve.
# done
# failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - geopandas=0.6.3
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/linux-64
# ...

# %%
# !git clone https://github.com/avanetten/cresi.git /opt/cresi/
# Out:
# Cloning into '/opt/cresi'...
# remote: Enumerating objects: 574, done.
# remote: Total 574 (delta 0), reused 0 (delta 0), pack-reused 574
# Receiving objects: 100% (574/574), 326.55 MiB | 23.36 MiB/s, done.
# Resolving deltas: 100% (290/290), done.

# %%
# !conda install geopandas=0.6.3 -c conda-forge --yes
# !apt install -y libgl1-mesa-glx --yes
# !source activate cresi && python -m ipykernel.kernelspec
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - geopandas=0.6.3
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2021.5.30  |       ha878542_0         136 KB  conda-forge
#     certifi-2021.5.30          |   py38h578d9bd_0         141 KB  conda-forge
#     conda-4.10.1               |   py38h578d9bd_0         3.1 MB  conda-forge
#     geopandas-0.6.3            |             py_0         903 KB  conda-forge
#     openssl-1.1.1k             |       h7f98852_0         2.1 MB  conda-forge
#     python_abi-3.8             |           2_cp38           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         6.3 MB
#
# ...

# %%
# !conda install -c conda-forge osmnx --yes
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - osmnx
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     boost-cpp-1.74.0           |       h312852a_4        16.3 MB  conda-forge
#     branca-0.4.2               |     pyhd8ed1ab_0          26 KB  conda-forge
#     c-ares-1.17.1              |       h7f98852_1         109 KB  conda-forge
#     cached-property-1.5.2      |       hd8ed1ab_1           4 KB  conda-forge
#     cached_property-1.5.2      |     pyha770c72_1          11 KB  conda-forge
#     cairo-1.16.0               |    h6cf1ce9_1008         1.5 MB  conda-forge
#     cffi-1.14.5                |   py38ha65f79e_0         227 KB  conda-forge
#     curl-7.77.0                |       hea6ffbf_0         149 KB  conda-forge
#     fiona-1.8.20               |   py38ha695d3a_1         1.2 MB  conda-forge
# ...

# %%
# !conda list
# Out:
# # packages in environment at /usr/local:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                        main
# _openmp_mutex             4.5                       1_gnu
# affine                    2.3.0                      py_0
# anyio                     2.2.0            py38h06a4308_1
# argon2-cffi               20.1.0           py38h27cfd23_1
# async_generator           1.10               pyhd3eb1b0_0
# attrs                     21.2.0             pyhd3eb1b0_0
# babel                     2.9.1              pyhd3eb1b0_0
# backcall                  0.2.0              pyhd3eb1b0_0
# blas                      1.0                         mkl
# bleach                    3.3.0              pyhd3eb1b0_0
# boost-cpp                 1.74.0               h312852a_4    conda-forge
# branca                    0.4.2              pyhd8ed1ab_0    conda-forge
# brotlipy                  0.7.0           py38h27cfd23_1003
# ...

# %% [markdown]
# # Training:

# %%
# !python /opt/cresi/cresi/00_gen_folds.py /opt/cresi/cresi/configs/sn5_baseline.json
# Out:
# 00_gen_folds.py: path_images_train: ['/content/drive/Shareddrives/CS482_Project/cresi_data/8bit/PS-RGB']
# train_files[:10]: ['SN5_roads_train_AOI_8_Mumbai_PS-MS_chip0.tif', 'SN5_roads_train_AOI_8_Mumbai_PS-MS_chip183.tif', 'SN5_roads_train_AOI_8_Mumbai_PS-MS_chip163.tif', 'SN5_roads_train_AOI_8_Mumbai_PS-MS_chip103.tif', 'SN5_roads_train_AOI_8_Mumbai_PS-MS_chip143.tif', 'SN5_roads_train_AOI_8_Mumbai_PS-MS_chip282.tif', 'SN5_roads_train_AOI_8_Mumbai_PS-MS_chip222.tif', 'SN5_roads_train_AOI_8_Mumbai_PS-MS_chip123.tif', 'SN5_roads_train_AOI_8_Mumbai_PS-MS_chip242.tif', 'SN5_roads_train_AOI_8_Mumbai_PS-MS_chip262.tif']
# folds_save_path: /content/drive/Shareddrives/CS482_Project/cresi_data/results/weights/sn5_baseline/folds5.csv

# %%
# !python /opt/cresi/cresi/01_train.py /opt/cresi/cresi/configs/sn5_baseline.json --fold=0
# Out:
# log_file: /content/drive/Shareddrives/CS482_Project/cresi_data/results/weights/sn5_baseline/train.log
# paths: {'masks': '/content/drive/Shareddrives/CS482_Project/cresi_data/cresi_train/train_mask_binned_mc', 'images': '/content/drive/Shareddrives/CS482_Project/cresi_data/8bit/PS-RGB'}
# fn_mapping: {'masks': <function <lambda> at 0x7f9d4cea6af0>}
# image_suffix:
# log     : INFO     Training: weight_save_path: /content/drive/Shareddrives/CS482_Project/cresi_data/results/weights/sn5_baseline
# log     : INFO     len ds: 944
# log     : INFO     folds_file_loc: /content/drive/Shareddrives/CS482_Project/cresi_data/results/weights/sn5_baseline/folds5.csv
# log     : INFO     save_path: /content/drive/Shareddrives/CS482_Project/cresi_data/results/weights/sn5_baseline
# ...

# %%
# %cd ..
# Out:
# /
